# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignment page](https://bcourses.berkeley.edu/courses/1453965/assignments/7738616) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs294_129.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs294_129.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs294_129/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs294_129.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs294_129.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [1e5, 1e6, 1e7]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        # Train
        svm = LinearSVM()
        svm.train(
            X_train_feats, 
            y_train, 
            learning_rate=lr, 
            reg=reg, 
            num_iters=2000, 
            verbose=True
        )
        
        # Training accuracy
        y_train_pred_cv = svm.predict(X_train_feats)
        train_accuracy_cv = np.mean(y_train == y_train_pred_cv)
        
        # Validation accuracy
        y_val_pred_cv = svm.predict(X_val_feats)
        val_accuracy_cv = np.mean(y_val == y_val_pred_cv)
        
        if val_accuracy_cv > best_val:
            best_val = val_accuracy_cv
            best_svm = svm
        results[(lr, reg)] = (train_accuracy_cv, val_accuracy_cv)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 2000: loss 84.251217
# iteration 100 / 2000: loss 82.751044
# iteration 200 / 2000: loss 81.304801
# iteration 300 / 2000: loss 79.871774
# iteration 400 / 2000: loss 78.462602
# iteration 500 / 2000: loss 77.078587
# iteration 600 / 2000: loss 75.732491
# iteration 700 / 2000: loss 74.414986
# iteration 800 / 2000: loss 73.122815
# iteration 900 / 2000: loss 71.857192
# iteration 1000 / 2000: loss 70.619123
# iteration 1100 / 2000: loss 69.390312
# iteration 1200 / 2000: loss 68.200426
# iteration 1300 / 2000: loss 67.018797
# iteration 1400 / 2000: loss 65.883825
# iteration 1500 / 2000: loss 64.747589
# iteration 1600 / 2000: loss 63.640679
# iteration 1700 / 2000: loss 62.551402
# iteration 1800 / 2000: loss 61.507183
# iteration 1900 / 2000: loss 60.461427
# iteration 0 / 2000: loss 804.654676
# iteration 100 / 2000: loss 660.379377
# iteration 200 / 2000: loss 542.233723
# iteration 300 / 2000: loss 445.552356
# iteration 400 / 2000: loss 366.370682
# iteration 500 / 2000: loss 301.566956
# iteration 600 / 2000: loss 248.504115
# iteration 700 / 2000: loss 205.067557
# iteration 800 / 2000: loss 169.512794
# iteration 900 / 2000: loss 140.409012
# iteration 1000 / 2000: loss 116.577661
# iteration 1100 / 2000: loss 97.063913
# iteration 1200 / 2000: loss 81.093579
# iteration 1300 / 2000: loss 68.023200
# iteration 1400 / 2000: loss 57.313567
# iteration 1500 / 2000: loss 48.554669
# iteration 1600 / 2000: loss 41.379079
# iteration 1700 / 2000: loss 35.508242
# iteration 1800 / 2000: loss 30.702898
# iteration 1900 / 2000: loss 26.767221
# iteration 0 / 2000: loss 7268.275976
# iteration 100 / 2000: loss 981.592094
# iteration 200 / 2000: loss 139.307917
# iteration 300 / 2000: loss 26.459085
# iteration 400 / 2000: loss 11.339066
# iteration 500 / 2000: loss 9.313420
# iteration 600 / 2000: loss 9.041989
# iteration 700 / 2000: loss 9.005622
# iteration 800 / 2000: loss 9.000748
# iteration 900 / 2000: loss 9.000097
# iteration 1000 / 2000: loss 9.000011
# iteration 1100 / 2000: loss 8.999998
# iteration 1200 / 2000: loss 8.999997
# iteration 1300 / 2000: loss 8.999997
# iteration 1400 / 2000: loss 8.999996
# iteration 1500 / 2000: loss 8.999997
# iteration 1600 / 2000: loss 8.999997
# iteration 1700 / 2000: loss 8.999996
# iteration 1800 / 2000: loss 8.999996
# iteration 1900 / 2000: loss 8.999997
# iteration 0 / 2000: loss 87.634960
# iteration 100 / 2000: loss 73.370756
# iteration 200 / 2000: loss 61.679609
# iteration 300 / 2000: loss 52.134441
# iteration 400 / 2000: loss 44.309531
# iteration 500 / 2000: loss 37.911291
# iteration 600 / 2000: loss 32.670739
# iteration 700 / 2000: loss 28.369301
# iteration 800 / 2000: loss 24.863812
# iteration 900 / 2000: loss 21.986474
# iteration 1000 / 2000: loss 19.629686
# iteration 1100 / 2000: loss 17.700509
# iteration 1200 / 2000: loss 16.123204
# iteration 1300 / 2000: loss 14.828218
# iteration 1400 / 2000: loss 13.772853
# iteration 1500 / 2000: loss 12.907671
# iteration 1600 / 2000: loss 12.197820
# iteration 1700 / 2000: loss 11.618775
# iteration 1800 / 2000: loss 11.144602
# iteration 1900 / 2000: loss 10.753469
# iteration 0 / 2000: loss 764.796573
# iteration 100 / 2000: loss 110.257265
# iteration 200 / 2000: loss 22.568471
# iteration 300 / 2000: loss 10.817728
# iteration 400 / 2000: loss 9.243474
# iteration 500 / 2000: loss 9.032618
# iteration 600 / 2000: loss 9.004340
# iteration 700 / 2000: loss 9.000545
# iteration 800 / 2000: loss 9.000045
# iteration 900 / 2000: loss 8.999978
# iteration 1000 / 2000: loss 8.999967
# iteration 1100 / 2000: loss 8.999971
# iteration 1200 / 2000: loss 8.999959
# iteration 1300 / 2000: loss 8.999962
# iteration 1400 / 2000: loss 8.999962
# iteration 1500 / 2000: loss 8.999967
# iteration 1600 / 2000: loss 8.999966
# iteration 1700 / 2000: loss 8.999967
# iteration 1800 / 2000: loss 8.999966
# iteration 1900 / 2000: loss 8.999962
# iteration 0 / 2000: loss 8034.675758
# iteration 100 / 2000: loss 9.000003
# iteration 200 / 2000: loss 8.999997
# iteration 300 / 2000: loss 8.999996
# iteration 400 / 2000: loss 8.999997
# iteration 500 / 2000: loss 8.999997
# iteration 600 / 2000: loss 8.999996
# iteration 700 / 2000: loss 8.999997
# iteration 800 / 2000: loss 8.999996
# iteration 900 / 2000: loss 8.999997
# iteration 1000 / 2000: loss 8.999997
# iteration 1100 / 2000: loss 8.999997
# iteration 1200 / 2000: loss 8.999997
# iteration 1300 / 2000: loss 8.999996
# iteration 1400 / 2000: loss 8.999996
# iteration 1500 / 2000: loss 8.999996
# iteration 1600 / 2000: loss 8.999996
# iteration 1700 / 2000: loss 8.999996
# iteration 1800 / 2000: loss 8.999997
# iteration 1900 / 2000: loss 8.999997
# iteration 0 / 2000: loss 82.990107
# iteration 100 / 2000: loss 18.908931
# iteration 200 / 2000: loss 10.328062
# iteration 300 / 2000: loss 9.177527
# iteration 400 / 2000: loss 9.023342
# iteration 500 / 2000: loss 9.002851
# iteration 600 / 2000: loss 9.000106
# iteration 700 / 2000: loss 8.999729
# iteration 800 / 2000: loss 8.999751
# iteration 900 / 2000: loss 8.999679
# iteration 1000 / 2000: loss 8.999643
# iteration 1100 / 2000: loss 8.999682
# iteration 1200 / 2000: loss 8.999665
# iteration 1300 / 2000: loss 8.999652
# iteration 1400 / 2000: loss 8.999599
# iteration 1500 / 2000: loss 8.999677
# iteration 1600 / 2000: loss 8.999653
# iteration 1700 / 2000: loss 8.999668
# iteration 1800 / 2000: loss 8.999568
# iteration 1900 / 2000: loss 8.999746
# iteration 0 / 2000: loss 761.294117
# iteration 100 / 2000: loss 8.999962
# iteration 200 / 2000: loss 8.999968
# iteration 300 / 2000: loss 8.999967
# iteration 400 / 2000: loss 8.999961
# iteration 500 / 2000: loss 8.999959
# iteration 600 / 2000: loss 8.999967
# iteration 700 / 2000: loss 8.999958
# iteration 800 / 2000: loss 8.999963
# iteration 900 / 2000: loss 8.999961
# iteration 1000 / 2000: loss 8.999971
# iteration 1100 / 2000: loss 8.999973
# iteration 1200 / 2000: loss 8.999964
# iteration 1300 / 2000: loss 8.999965
# iteration 1400 / 2000: loss 8.999972
# iteration 1500 / 2000: loss 8.999965
# iteration 1600 / 2000: loss 8.999967
# iteration 1700 / 2000: loss 8.999965
# iteration 1800 / 2000: loss 8.999972
# iteration 1900 / 2000: loss 8.999978
# iteration 0 / 2000: loss 7725.155771
# iteration 100 / 2000: loss 9.000000
# iteration 200 / 2000: loss 9.000000
# iteration 300 / 2000: loss 9.000001
# iteration 400 / 2000: loss 9.000000
# iteration 500 / 2000: loss 8.999999
# iteration 600 / 2000: loss 9.000000
# iteration 700 / 2000: loss 9.000001
# iteration 800 / 2000: loss 8.999999
# iteration 900 / 2000: loss 8.999999
# iteration 1000 / 2000: loss 8.999999
# iteration 1100 / 2000: loss 9.000001
# iteration 1200 / 2000: loss 9.000000
# iteration 1300 / 2000: loss 9.000000
# iteration 1400 / 2000: loss 9.000000
# iteration 1500 / 2000: loss 9.000000
# iteration 1600 / 2000: loss 9.000001
# iteration 1700 / 2000: loss 9.000000
# iteration 1800 / 2000: loss 8.999999
# iteration 1900 / 2000: loss 8.999999
# lr 1.000000e-09 reg 1.000000e+05 train accuracy: 0.091306 val accuracy: 0.087000
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.109020 val accuracy: 0.103000
# lr 1.000000e-09 reg 1.000000e+07 train accuracy: 0.414837 val accuracy: 0.416000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.094714 val accuracy: 0.088000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.412327 val accuracy: 0.424000
# lr 1.000000e-08 reg 1.000000e+07 train accuracy: 0.398694 val accuracy: 0.397000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.412796 val accuracy: 0.414000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.405143 val accuracy: 0.385000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.317184 val accuracy: 0.287000
# best validation accuracy achieved during cross-validation: 0.424000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.421

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
# - Certain misclassification actually make sense that they are quite similar.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 155)

# %%
from cs294_129.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################best_stats = None
learning_rates = np.logspace(-10, 0, 10) 
# np.logspace(-10, 10, 8) #-10, -9, -8, -7, -6, -5, -4
regularization_strengths = np.logspace(-5, 5, 10) 
# causes numeric issues: np.logspace(-5, 5, 8) #[-4, -3, -2, -1, 1, 2, 3, 4, 5, 6]
best_stats = None
results = {}

for lr in learning_rates:
    for reg in regularization_strengths:
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)

        # Train the network
        stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                    num_iters=1000, batch_size=200,
                    learning_rate=lr, learning_rate_decay=0.80,
                    reg=reg, verbose=True)

        # Predict on the validation set
        val_acc = (net.predict(X_val_feats) == y_val).mean()
        print 'Validation accuracy: ', val_acc

        if val_acc > best_val:
            best_val = val_acc
            best_net = net
            best_stats = stats

        results[(lr, reg)] = val_acc
            
# Print out results.
for lr, reg in sorted(results):
    val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train val accuracy: %f' % (
                lr, reg, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val

# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(best_stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(best_stats['train_acc_history'], label='train')
plt.plot(best_stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.099
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.101
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302586
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302586
# Validation accuracy:  0.121
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302594
# iteration 200 / 1000: loss 2.302594
# iteration 300 / 1000: loss 2.302594
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302594
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302594
# iteration 900 / 1000: loss 2.302594
# Validation accuracy:  0.097
# iteration 0 / 1000: loss 2.302699
# iteration 100 / 1000: loss 2.302699
# iteration 200 / 1000: loss 2.302699
# iteration 300 / 1000: loss 2.302700
# iteration 400 / 1000: loss 2.302699
# iteration 500 / 1000: loss 2.302700
# iteration 600 / 1000: loss 2.302699
# iteration 700 / 1000: loss 2.302700
# iteration 800 / 1000: loss 2.302699
# iteration 900 / 1000: loss 2.302700
# Validation accuracy:  0.091
# iteration 0 / 1000: loss 2.304056
# iteration 100 / 1000: loss 2.304057
# iteration 200 / 1000: loss 2.304056
# iteration 300 / 1000: loss 2.304057
# iteration 400 / 1000: loss 2.304056
# iteration 500 / 1000: loss 2.304057
# iteration 600 / 1000: loss 2.304056
# iteration 700 / 1000: loss 2.304056
# iteration 800 / 1000: loss 2.304057
# iteration 900 / 1000: loss 2.304056
# Validation accuracy:  0.092
# iteration 0 / 1000: loss 2.321840
# iteration 100 / 1000: loss 2.321840
# iteration 200 / 1000: loss 2.321840
# iteration 300 / 1000: loss 2.321840
# iteration 400 / 1000: loss 2.321840
# iteration 500 / 1000: loss 2.321839
# iteration 600 / 1000: loss 2.321840
# iteration 700 / 1000: loss 2.321840
# iteration 800 / 1000: loss 2.321840
# iteration 900 / 1000: loss 2.321840
# Validation accuracy:  0.095
# iteration 0 / 1000: loss 2.549274
# iteration 100 / 1000: loss 2.549272
# iteration 200 / 1000: loss 2.549269
# iteration 300 / 1000: loss 2.549268
# iteration 400 / 1000: loss 2.549266
# iteration 500 / 1000: loss 2.549264
# iteration 600 / 1000: loss 2.549262
# iteration 700 / 1000: loss 2.549261
# iteration 800 / 1000: loss 2.549259
# iteration 900 / 1000: loss 2.549258
# Validation accuracy:  0.111
# iteration 0 / 1000: loss 5.507640
# iteration 100 / 1000: loss 5.507243
# iteration 200 / 1000: loss 5.506845
# iteration 300 / 1000: loss 5.506491
# iteration 400 / 1000: loss 5.506174
# iteration 500 / 1000: loss 5.505862
# iteration 600 / 1000: loss 5.505608
# iteration 700 / 1000: loss 5.505354
# iteration 800 / 1000: loss 5.505133
# iteration 900 / 1000: loss 5.504930
# Validation accuracy:  0.111
# iteration 0 / 1000: loss 43.845698
# iteration 100 / 1000: loss 43.779116
# iteration 200 / 1000: loss 43.712806
# iteration 300 / 1000: loss 43.653747
# iteration 400 / 1000: loss 43.600851
# iteration 500 / 1000: loss 43.548974
# iteration 600 / 1000: loss 43.506759
# iteration 700 / 1000: loss 43.464587
# iteration 800 / 1000: loss 43.427849
# iteration 900 / 1000: loss 43.394173
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.119
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.103
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302586
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302586
# Validation accuracy:  0.091
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302594
# iteration 200 / 1000: loss 2.302594
# iteration 300 / 1000: loss 2.302594
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302594
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302594
# iteration 900 / 1000: loss 2.302594
# Validation accuracy:  0.111
# iteration 0 / 1000: loss 2.302700
# iteration 100 / 1000: loss 2.302700
# iteration 200 / 1000: loss 2.302700
# iteration 300 / 1000: loss 2.302699
# iteration 400 / 1000: loss 2.302700
# iteration 500 / 1000: loss 2.302700
# iteration 600 / 1000: loss 2.302699
# iteration 700 / 1000: loss 2.302700
# iteration 800 / 1000: loss 2.302700
# iteration 900 / 1000: loss 2.302700
# Validation accuracy:  0.083
# iteration 0 / 1000: loss 2.304067
# iteration 100 / 1000: loss 2.304067
# iteration 200 / 1000: loss 2.304067
# iteration 300 / 1000: loss 2.304066
# iteration 400 / 1000: loss 2.304067
# iteration 500 / 1000: loss 2.304066
# iteration 600 / 1000: loss 2.304067
# iteration 700 / 1000: loss 2.304066
# iteration 800 / 1000: loss 2.304067
# iteration 900 / 1000: loss 2.304066
# Validation accuracy:  0.061
# iteration 0 / 1000: loss 2.321561
# iteration 100 / 1000: loss 2.321560
# iteration 200 / 1000: loss 2.321560
# iteration 300 / 1000: loss 2.321560
# iteration 400 / 1000: loss 2.321560
# iteration 500 / 1000: loss 2.321560
# iteration 600 / 1000: loss 2.321560
# iteration 700 / 1000: loss 2.321559
# iteration 800 / 1000: loss 2.321560
# iteration 900 / 1000: loss 2.321559
# Validation accuracy:  0.122
# iteration 0 / 1000: loss 2.550137
# iteration 100 / 1000: loss 2.550106
# iteration 200 / 1000: loss 2.550076
# iteration 300 / 1000: loss 2.550048
# iteration 400 / 1000: loss 2.550024
# iteration 500 / 1000: loss 2.549999
# iteration 600 / 1000: loss 2.549980
# iteration 700 / 1000: loss 2.549960
# iteration 800 / 1000: loss 2.549943
# iteration 900 / 1000: loss 2.549927
# Validation accuracy:  0.106
# iteration 0 / 1000: loss 5.498423
# iteration 100 / 1000: loss 5.493300
# iteration 200 / 1000: loss 5.488200
# iteration 300 / 1000: loss 5.483656
# iteration 400 / 1000: loss 5.479587
# iteration 500 / 1000: loss 5.475596
# iteration 600 / 1000: loss 5.472349
# iteration 700 / 1000: loss 5.469104
# iteration 800 / 1000: loss 5.466278
# iteration 900 / 1000: loss 5.463688
# Validation accuracy:  0.106
# iteration 0 / 1000: loss 43.513909
# iteration 100 / 1000: loss 42.668895
# iteration 200 / 1000: loss 41.843251
# iteration 300 / 1000: loss 41.121041
# iteration 400 / 1000: loss 40.484550
# iteration 500 / 1000: loss 39.869674
# iteration 600 / 1000: loss 39.376086
# iteration 700 / 1000: loss 38.888984
# iteration 800 / 1000: loss 38.469459
# iteration 900 / 1000: loss 38.088807
# Validation accuracy:  0.1
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.099
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.116
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.131
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302594
# iteration 200 / 1000: loss 2.302594
# iteration 300 / 1000: loss 2.302594
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302594
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302594
# iteration 900 / 1000: loss 2.302594
# Validation accuracy:  0.094
# iteration 0 / 1000: loss 2.302700
# iteration 100 / 1000: loss 2.302700
# iteration 200 / 1000: loss 2.302700
# iteration 300 / 1000: loss 2.302700
# iteration 400 / 1000: loss 2.302700
# iteration 500 / 1000: loss 2.302700
# iteration 600 / 1000: loss 2.302701
# iteration 700 / 1000: loss 2.302700
# iteration 800 / 1000: loss 2.302700
# iteration 900 / 1000: loss 2.302700
# Validation accuracy:  0.097
# iteration 0 / 1000: loss 2.304065
# iteration 100 / 1000: loss 2.304065
# iteration 200 / 1000: loss 2.304065
# iteration 300 / 1000: loss 2.304065
# iteration 400 / 1000: loss 2.304065
# iteration 500 / 1000: loss 2.304065
# iteration 600 / 1000: loss 2.304065
# iteration 700 / 1000: loss 2.304065
# iteration 800 / 1000: loss 2.304065
# iteration 900 / 1000: loss 2.304065
# Validation accuracy:  0.131
# iteration 0 / 1000: loss 2.321699
# iteration 100 / 1000: loss 2.321697
# iteration 200 / 1000: loss 2.321695
# iteration 300 / 1000: loss 2.321692
# iteration 400 / 1000: loss 2.321690
# iteration 500 / 1000: loss 2.321688
# iteration 600 / 1000: loss 2.321687
# iteration 700 / 1000: loss 2.321685
# iteration 800 / 1000: loss 2.321684
# iteration 900 / 1000: loss 2.321683
# Validation accuracy:  0.116
# iteration 0 / 1000: loss 2.552634
# iteration 100 / 1000: loss 2.552234
# iteration 200 / 1000: loss 2.551835
# iteration 300 / 1000: loss 2.551479
# iteration 400 / 1000: loss 2.551161
# iteration 500 / 1000: loss 2.550848
# iteration 600 / 1000: loss 2.550595
# iteration 700 / 1000: loss 2.550341
# iteration 800 / 1000: loss 2.550120
# iteration 900 / 1000: loss 2.549917
# Validation accuracy:  0.084
# iteration 0 / 1000: loss 5.492069
# iteration 100 / 1000: loss 5.426670
# iteration 200 / 1000: loss 5.362771
# iteration 300 / 1000: loss 5.306877
# iteration 400 / 1000: loss 5.257617
# iteration 500 / 1000: loss 5.210029
# iteration 600 / 1000: loss 5.171829
# iteration 700 / 1000: loss 5.134131
# iteration 800 / 1000: loss 5.101662
# iteration 900 / 1000: loss 5.072202
# Validation accuracy:  0.099
# iteration 0 / 1000: loss 43.322984
# iteration 100 / 1000: loss 33.687486
# iteration 200 / 1000: loss 26.331373
# iteration 300 / 1000: loss 21.238071
# iteration 400 / 1000: loss 17.595762
# iteration 500 / 1000: loss 14.701672
# iteration 600 / 1000: loss 12.753990
# iteration 700 / 1000: loss 11.112254
# iteration 800 / 1000: loss 9.892682
# iteration 900 / 1000: loss 8.922926
# Validation accuracy:  0.121
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.1
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.093
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302586
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302586
# Validation accuracy:  0.132
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302594
# iteration 200 / 1000: loss 2.302594
# iteration 300 / 1000: loss 2.302594
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302594
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302594
# iteration 900 / 1000: loss 2.302594
# Validation accuracy:  0.098
# iteration 0 / 1000: loss 2.302700
# iteration 100 / 1000: loss 2.302700
# iteration 200 / 1000: loss 2.302700
# iteration 300 / 1000: loss 2.302700
# iteration 400 / 1000: loss 2.302700
# iteration 500 / 1000: loss 2.302700
# iteration 600 / 1000: loss 2.302700
# iteration 700 / 1000: loss 2.302700
# iteration 800 / 1000: loss 2.302700
# iteration 900 / 1000: loss 2.302700
# Validation accuracy:  0.104
# iteration 0 / 1000: loss 2.304070
# iteration 100 / 1000: loss 2.304070
# iteration 200 / 1000: loss 2.304070
# iteration 300 / 1000: loss 2.304070
# iteration 400 / 1000: loss 2.304070
# iteration 500 / 1000: loss 2.304069
# iteration 600 / 1000: loss 2.304069
# iteration 700 / 1000: loss 2.304069
# iteration 800 / 1000: loss 2.304069
# iteration 900 / 1000: loss 2.304069
# Validation accuracy:  0.092
# iteration 0 / 1000: loss 2.321787
# iteration 100 / 1000: loss 2.321756
# iteration 200 / 1000: loss 2.321726
# iteration 300 / 1000: loss 2.321698
# iteration 400 / 1000: loss 2.321674
# iteration 500 / 1000: loss 2.321650
# iteration 600 / 1000: loss 2.321630
# iteration 700 / 1000: loss 2.321611
# iteration 800 / 1000: loss 2.321594
# iteration 900 / 1000: loss 2.321578
# Validation accuracy:  0.09
# iteration 0 / 1000: loss 2.551251
# iteration 100 / 1000: loss 2.546152
# iteration 200 / 1000: loss 2.541170
# iteration 300 / 1000: loss 2.536813
# iteration 400 / 1000: loss 2.532972
# iteration 500 / 1000: loss 2.529262
# iteration 600 / 1000: loss 2.526284
# iteration 700 / 1000: loss 2.523344
# iteration 800 / 1000: loss 2.520813
# iteration 900 / 1000: loss 2.518516
# Validation accuracy:  0.128
# iteration 0 / 1000: loss 5.506717
# iteration 100 / 1000: loss 4.754082
# iteration 200 / 1000: loss 4.179490
# iteration 300 / 1000: loss 3.781649
# iteration 400 / 1000: loss 3.497146
# iteration 500 / 1000: loss 3.271086
# iteration 600 / 1000: loss 3.118952
# iteration 700 / 1000: loss 2.990715
# iteration 800 / 1000: loss 2.895453
# iteration 900 / 1000: loss 2.819704
# Validation accuracy:  0.08
# iteration 0 / 1000: loss 43.373022
# iteration 100 / 1000: loss 3.560371
# iteration 200 / 1000: loss 2.341445
# iteration 300 / 1000: loss 2.304337
# iteration 400 / 1000: loss 2.302694
# iteration 500 / 1000: loss 2.302592
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.074
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302586
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302586
# Validation accuracy:  0.107
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302594
# iteration 200 / 1000: loss 2.302594
# iteration 300 / 1000: loss 2.302594
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302594
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302594
# iteration 900 / 1000: loss 2.302594
# Validation accuracy:  0.089
# iteration 0 / 1000: loss 2.302699
# iteration 100 / 1000: loss 2.302700
# iteration 200 / 1000: loss 2.302699
# iteration 300 / 1000: loss 2.302699
# iteration 400 / 1000: loss 2.302699
# iteration 500 / 1000: loss 2.302699
# iteration 600 / 1000: loss 2.302699
# iteration 700 / 1000: loss 2.302699
# iteration 800 / 1000: loss 2.302700
# iteration 900 / 1000: loss 2.302699
# Validation accuracy:  0.09
# iteration 0 / 1000: loss 2.304071
# iteration 100 / 1000: loss 2.304069
# iteration 200 / 1000: loss 2.304067
# iteration 300 / 1000: loss 2.304065
# iteration 400 / 1000: loss 2.304062
# iteration 500 / 1000: loss 2.304061
# iteration 600 / 1000: loss 2.304059
# iteration 700 / 1000: loss 2.304057
# iteration 800 / 1000: loss 2.304056
# iteration 900 / 1000: loss 2.304055
# Validation accuracy:  0.088
# iteration 0 / 1000: loss 2.321895
# iteration 100 / 1000: loss 2.321499
# iteration 200 / 1000: loss 2.321112
# iteration 300 / 1000: loss 2.320773
# iteration 400 / 1000: loss 2.320475
# iteration 500 / 1000: loss 2.320187
# iteration 600 / 1000: loss 2.319956
# iteration 700 / 1000: loss 2.319728
# iteration 800 / 1000: loss 2.319531
# iteration 900 / 1000: loss 2.319353
# Validation accuracy:  0.121
# iteration 0 / 1000: loss 2.551216
# iteration 100 / 1000: loss 2.492814
# iteration 200 / 1000: loss 2.448228
# iteration 300 / 1000: loss 2.417356
# iteration 400 / 1000: loss 2.395280
# iteration 500 / 1000: loss 2.377738
# iteration 600 / 1000: loss 2.365933
# iteration 700 / 1000: loss 2.355982
# iteration 800 / 1000: loss 2.348590
# iteration 900 / 1000: loss 2.342712
# Validation accuracy:  0.102
# iteration 0 / 1000: loss 5.464837
# iteration 100 / 1000: loss 2.399429
# iteration 200 / 1000: loss 2.305577
# iteration 300 / 1000: loss 2.302720
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.078
# iteration 0 / 1000: loss 43.661347
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302584
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.119
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302584
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.078
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302587
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.088
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302594
# iteration 200 / 1000: loss 2.302594
# iteration 300 / 1000: loss 2.302593
# iteration 400 / 1000: loss 2.302595
# iteration 500 / 1000: loss 2.302595
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302593
# iteration 800 / 1000: loss 2.302594
# iteration 900 / 1000: loss 2.302594
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302700
# iteration 100 / 1000: loss 2.302699
# iteration 200 / 1000: loss 2.302698
# iteration 300 / 1000: loss 2.302700
# iteration 400 / 1000: loss 2.302698
# iteration 500 / 1000: loss 2.302700
# iteration 600 / 1000: loss 2.302701
# iteration 700 / 1000: loss 2.302699
# iteration 800 / 1000: loss 2.302698
# iteration 900 / 1000: loss 2.302699
# Validation accuracy:  0.113
# iteration 0 / 1000: loss 2.304063
# iteration 100 / 1000: loss 2.304032
# iteration 200 / 1000: loss 2.304004
# iteration 300 / 1000: loss 2.303977
# iteration 400 / 1000: loss 2.303955
# iteration 500 / 1000: loss 2.303931
# iteration 600 / 1000: loss 2.303915
# iteration 700 / 1000: loss 2.303895
# iteration 800 / 1000: loss 2.303882
# iteration 900 / 1000: loss 2.303869
# Validation accuracy:  0.094
# iteration 0 / 1000: loss 2.321780
# iteration 100 / 1000: loss 2.317272
# iteration 200 / 1000: loss 2.313829
# iteration 300 / 1000: loss 2.311446
# iteration 400 / 1000: loss 2.309741
# iteration 500 / 1000: loss 2.308386
# iteration 600 / 1000: loss 2.307474
# iteration 700 / 1000: loss 2.306706
# iteration 800 / 1000: loss 2.306137
# iteration 900 / 1000: loss 2.305682
# Validation accuracy:  0.078
# iteration 0 / 1000: loss 2.550403
# iteration 100 / 1000: loss 2.310175
# iteration 200 / 1000: loss 2.302820
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302584
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.078
# iteration 0 / 1000: loss 5.533498
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Validation accuracy:  0.119
# iteration 0 / 1000: loss 43.319185
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302584
# iteration 200 / 1000: loss 2.302575
# iteration 300 / 1000: loss 2.302582
# iteration 400 / 1000: loss 2.302582
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302578
# iteration 700 / 1000: loss 2.302587
# iteration 800 / 1000: loss 2.302575
# iteration 900 / 1000: loss 2.302595
# Validation accuracy:  0.078
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302577
# iteration 200 / 1000: loss 2.302582
# iteration 300 / 1000: loss 2.302583
# iteration 400 / 1000: loss 2.302563
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302571
# iteration 700 / 1000: loss 2.302583
# iteration 800 / 1000: loss 2.302588
# iteration 900 / 1000: loss 2.302580
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302590
# iteration 300 / 1000: loss 2.302584
# iteration 400 / 1000: loss 2.302590
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302590
# iteration 700 / 1000: loss 2.302570
# iteration 800 / 1000: loss 2.302580
# iteration 900 / 1000: loss 2.302593
# Validation accuracy:  0.079
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302592
# iteration 200 / 1000: loss 2.302596
# iteration 300 / 1000: loss 2.302592
# iteration 400 / 1000: loss 2.302607
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302582
# iteration 700 / 1000: loss 2.302598
# iteration 800 / 1000: loss 2.302617
# iteration 900 / 1000: loss 2.302596
# Validation accuracy:  0.105
# iteration 0 / 1000: loss 2.302699
# iteration 100 / 1000: loss 2.302687
# iteration 200 / 1000: loss 2.302711
# iteration 300 / 1000: loss 2.302695
# iteration 400 / 1000: loss 2.302683
# iteration 500 / 1000: loss 2.302696
# iteration 600 / 1000: loss 2.302670
# iteration 700 / 1000: loss 2.302667
# iteration 800 / 1000: loss 2.302693
# iteration 900 / 1000: loss 2.302681
# Validation accuracy:  0.102
# iteration 0 / 1000: loss 2.304058
# iteration 100 / 1000: loss 2.303735
# iteration 200 / 1000: loss 2.303446
# iteration 300 / 1000: loss 2.303253
# iteration 400 / 1000: loss 2.303149
# iteration 500 / 1000: loss 2.303032
# iteration 600 / 1000: loss 2.302954
# iteration 700 / 1000: loss 2.302915
# iteration 800 / 1000: loss 2.302853
# iteration 900 / 1000: loss 2.302823
# Validation accuracy:  0.079
# iteration 0 / 1000: loss 2.321648
# iteration 100 / 1000: loss 2.303164
# iteration 200 / 1000: loss 2.302608
# iteration 300 / 1000: loss 2.302603
# iteration 400 / 1000: loss 2.302567
# iteration 500 / 1000: loss 2.302567
# iteration 600 / 1000: loss 2.302574
# iteration 700 / 1000: loss 2.302574
# iteration 800 / 1000: loss 2.302594
# iteration 900 / 1000: loss 2.302565
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.549930
# iteration 100 / 1000: loss 2.302589
# iteration 200 / 1000: loss 2.302576
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302570
# iteration 600 / 1000: loss 2.302588
# iteration 700 / 1000: loss 2.302577
# iteration 800 / 1000: loss 2.302590
# iteration 900 / 1000: loss 2.302576
# Validation accuracy:  0.105
# iteration 0 / 1000: loss 5.513481
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 43.493166
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302641
# iteration 200 / 1000: loss 2.302645
# iteration 300 / 1000: loss 2.302637
# iteration 400 / 1000: loss 2.302614
# iteration 500 / 1000: loss 2.302420
# iteration 600 / 1000: loss 2.302897
# iteration 700 / 1000: loss 2.302559
# iteration 800 / 1000: loss 2.302577
# iteration 900 / 1000: loss 2.302492
# Validation accuracy:  0.078
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302547
# iteration 200 / 1000: loss 2.302572
# iteration 300 / 1000: loss 2.302368
# iteration 400 / 1000: loss 2.302799
# iteration 500 / 1000: loss 2.302709
# iteration 600 / 1000: loss 2.302542
# iteration 700 / 1000: loss 2.302472
# iteration 800 / 1000: loss 2.302404
# iteration 900 / 1000: loss 2.302399
# Validation accuracy:  0.102
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302622
# iteration 300 / 1000: loss 2.302592
# iteration 400 / 1000: loss 2.302496
# iteration 500 / 1000: loss 2.302597
# iteration 600 / 1000: loss 2.302614
# iteration 700 / 1000: loss 2.302410
# iteration 800 / 1000: loss 2.302360
# iteration 900 / 1000: loss 2.302644
# Validation accuracy:  0.098
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302484
# iteration 300 / 1000: loss 2.302663
# iteration 400 / 1000: loss 2.302361
# iteration 500 / 1000: loss 2.302729
# iteration 600 / 1000: loss 2.302620
# iteration 700 / 1000: loss 2.302241
# iteration 800 / 1000: loss 2.302422
# iteration 900 / 1000: loss 2.302560
# Validation accuracy:  0.107
# iteration 0 / 1000: loss 2.302700
# iteration 100 / 1000: loss 2.302691
# iteration 200 / 1000: loss 2.302698
# iteration 300 / 1000: loss 2.302871
# iteration 400 / 1000: loss 2.302796
# iteration 500 / 1000: loss 2.302784
# iteration 600 / 1000: loss 2.302590
# iteration 700 / 1000: loss 2.302458
# iteration 800 / 1000: loss 2.302704
# iteration 900 / 1000: loss 2.302574
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.304051
# iteration 100 / 1000: loss 2.302620
# iteration 200 / 1000: loss 2.302629
# iteration 300 / 1000: loss 2.302605
# iteration 400 / 1000: loss 2.302422
# iteration 500 / 1000: loss 2.302469
# iteration 600 / 1000: loss 2.302709
# iteration 700 / 1000: loss 2.302622
# iteration 800 / 1000: loss 2.302453
# iteration 900 / 1000: loss 2.302563
# Validation accuracy:  0.079
# iteration 0 / 1000: loss 2.321572
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302633
# iteration 300 / 1000: loss 2.302535
# iteration 400 / 1000: loss 2.302579
# iteration 500 / 1000: loss 2.302544
# iteration 600 / 1000: loss 2.302389
# iteration 700 / 1000: loss 2.302502
# iteration 800 / 1000: loss 2.302559
# iteration 900 / 1000: loss 2.302566
# Validation accuracy:  0.107
# iteration 0 / 1000: loss 2.549152
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 5.482037
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 43.686307
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.300641
# iteration 200 / 1000: loss 2.298168
# iteration 300 / 1000: loss 2.172082
# iteration 400 / 1000: loss 1.903007
# iteration 500 / 1000: loss 1.839821
# iteration 600 / 1000: loss 1.737461
# iteration 700 / 1000: loss 1.617373
# iteration 800 / 1000: loss 1.644900
# iteration 900 / 1000: loss 1.492000
# Validation accuracy:  0.43
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302750
# iteration 200 / 1000: loss 2.295657
# iteration 300 / 1000: loss 2.170563
# iteration 400 / 1000: loss 1.927658
# iteration 500 / 1000: loss 1.841996
# iteration 600 / 1000: loss 1.729160
# iteration 700 / 1000: loss 1.585944
# iteration 800 / 1000: loss 1.589625
# iteration 900 / 1000: loss 1.520863
# Validation accuracy:  0.44
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302285
# iteration 200 / 1000: loss 2.296075
# iteration 300 / 1000: loss 2.187861
# iteration 400 / 1000: loss 1.970941
# iteration 500 / 1000: loss 1.759263
# iteration 600 / 1000: loss 1.686192
# iteration 700 / 1000: loss 1.738604
# iteration 800 / 1000: loss 1.587690
# iteration 900 / 1000: loss 1.515253
# Validation accuracy:  0.444
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.303065
# iteration 200 / 1000: loss 2.299833
# iteration 300 / 1000: loss 2.219887
# iteration 400 / 1000: loss 2.104366
# iteration 500 / 1000: loss 1.903465
# iteration 600 / 1000: loss 1.892840
# iteration 700 / 1000: loss 1.692000
# iteration 800 / 1000: loss 1.759960
# iteration 900 / 1000: loss 1.697369
# Validation accuracy:  0.426
# iteration 0 / 1000: loss 2.302700
# iteration 100 / 1000: loss 2.302200
# iteration 200 / 1000: loss 2.302168
# iteration 300 / 1000: loss 2.300253
# iteration 400 / 1000: loss 2.303822
# iteration 500 / 1000: loss 2.302501
# iteration 600 / 1000: loss 2.300375
# iteration 700 / 1000: loss 2.301111
# iteration 800 / 1000: loss 2.302405
# iteration 900 / 1000: loss 2.301838
# Validation accuracy:  0.159
# iteration 0 / 1000: loss 2.304076
# iteration 100 / 1000: loss 2.301692
# iteration 200 / 1000: loss 2.302798
# iteration 300 / 1000: loss 2.301926
# iteration 400 / 1000: loss 2.300538
# iteration 500 / 1000: loss 2.302562
# iteration 600 / 1000: loss 2.302232
# iteration 700 / 1000: loss 2.301792
# iteration 800 / 1000: loss 2.302603
# iteration 900 / 1000: loss 2.303090
# Validation accuracy:  0.102
# iteration 0 / 1000: loss 2.321709
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.549148
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 5.498272
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 43.643874
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.669003
# iteration 200 / 1000: loss 1.279092
# iteration 300 / 1000: loss 1.340191
# iteration 400 / 1000: loss 1.197577
# iteration 500 / 1000: loss 1.037476
# iteration 600 / 1000: loss 1.057212
# iteration 700 / 1000: loss 1.082914
# iteration 800 / 1000: loss 1.001860
# iteration 900 / 1000: loss 0.998609
# Validation accuracy:  0.585
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.564272
# iteration 200 / 1000: loss 1.468079
# iteration 300 / 1000: loss 1.232859
# iteration 400 / 1000: loss 1.138331
# iteration 500 / 1000: loss 1.139383
# iteration 600 / 1000: loss 1.007931
# iteration 700 / 1000: loss 1.110317
# iteration 800 / 1000: loss 0.943099
# iteration 900 / 1000: loss 1.094169
# Validation accuracy:  0.585
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 1.541926
# iteration 200 / 1000: loss 1.250650
# iteration 300 / 1000: loss 1.383669
# iteration 400 / 1000: loss 1.248146
# iteration 500 / 1000: loss 1.133931
# iteration 600 / 1000: loss 1.283426
# iteration 700 / 1000: loss 1.167485
# iteration 800 / 1000: loss 1.332150
# iteration 900 / 1000: loss 1.068500
# Validation accuracy:  0.588
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 1.547265
# iteration 200 / 1000: loss 1.688720
# iteration 300 / 1000: loss 1.628868
# iteration 400 / 1000: loss 1.726958
# iteration 500 / 1000: loss 1.547369
# iteration 600 / 1000: loss 1.684541
# iteration 700 / 1000: loss 1.695081
# iteration 800 / 1000: loss 1.482464
# iteration 900 / 1000: loss 1.723866
# Validation accuracy:  0.489
# iteration 0 / 1000: loss 2.302700
# iteration 100 / 1000: loss 2.277843
# iteration 200 / 1000: loss 2.248048
# iteration 300 / 1000: loss 2.245856
# iteration 400 / 1000: loss 2.206502
# iteration 500 / 1000: loss 2.246659
# iteration 600 / 1000: loss 2.232738
# iteration 700 / 1000: loss 2.221615
# iteration 800 / 1000: loss 2.191078
# iteration 900 / 1000: loss 2.190127
# Validation accuracy:  0.267
# iteration 0 / 1000: loss 2.304070
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.321817
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 2.546751
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 5.521798
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# iteration 0 / 1000: loss 43.633884
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# Validation accuracy:  0.087
# lr 1.000000e-10 reg 1.000000e-05 train val accuracy: 0.099000
# lr 1.000000e-10 reg 1.291550e-04 train val accuracy: 0.101000
# lr 1.000000e-10 reg 1.668101e-03 train val accuracy: 0.121000
# lr 1.000000e-10 reg 2.154435e-02 train val accuracy: 0.097000
# lr 1.000000e-10 reg 2.782559e-01 train val accuracy: 0.091000
# lr 1.000000e-10 reg 3.593814e+00 train val accuracy: 0.092000
# lr 1.000000e-10 reg 4.641589e+01 train val accuracy: 0.095000
# lr 1.000000e-10 reg 5.994843e+02 train val accuracy: 0.111000
# lr 1.000000e-10 reg 7.742637e+03 train val accuracy: 0.111000
# lr 1.000000e-10 reg 1.000000e+05 train val accuracy: 0.087000
# lr 1.291550e-09 reg 1.000000e-05 train val accuracy: 0.119000
# lr 1.291550e-09 reg 1.291550e-04 train val accuracy: 0.103000
# lr 1.291550e-09 reg 1.668101e-03 train val accuracy: 0.091000
# lr 1.291550e-09 reg 2.154435e-02 train val accuracy: 0.111000
# lr 1.291550e-09 reg 2.782559e-01 train val accuracy: 0.083000
# lr 1.291550e-09 reg 3.593814e+00 train val accuracy: 0.061000
# lr 1.291550e-09 reg 4.641589e+01 train val accuracy: 0.122000
# lr 1.291550e-09 reg 5.994843e+02 train val accuracy: 0.106000
# lr 1.291550e-09 reg 7.742637e+03 train val accuracy: 0.106000
# lr 1.291550e-09 reg 1.000000e+05 train val accuracy: 0.100000
# lr 1.668101e-08 reg 1.000000e-05 train val accuracy: 0.099000
# lr 1.668101e-08 reg 1.291550e-04 train val accuracy: 0.116000
# lr 1.668101e-08 reg 1.668101e-03 train val accuracy: 0.131000
# lr 1.668101e-08 reg 2.154435e-02 train val accuracy: 0.094000
# lr 1.668101e-08 reg 2.782559e-01 train val accuracy: 0.097000
# lr 1.668101e-08 reg 3.593814e+00 train val accuracy: 0.131000
# lr 1.668101e-08 reg 4.641589e+01 train val accuracy: 0.116000
# lr 1.668101e-08 reg 5.994843e+02 train val accuracy: 0.084000
# lr 1.668101e-08 reg 7.742637e+03 train val accuracy: 0.099000
# lr 1.668101e-08 reg 1.000000e+05 train val accuracy: 0.121000
# lr 2.154435e-07 reg 1.000000e-05 train val accuracy: 0.100000
# lr 2.154435e-07 reg 1.291550e-04 train val accuracy: 0.093000
# lr 2.154435e-07 reg 1.668101e-03 train val accuracy: 0.132000
# lr 2.154435e-07 reg 2.154435e-02 train val accuracy: 0.098000
# lr 2.154435e-07 reg 2.782559e-01 train val accuracy: 0.104000
# lr 2.154435e-07 reg 3.593814e+00 train val accuracy: 0.092000
# lr 2.154435e-07 reg 4.641589e+01 train val accuracy: 0.090000
# lr 2.154435e-07 reg 5.994843e+02 train val accuracy: 0.128000
# lr 2.154435e-07 reg 7.742637e+03 train val accuracy: 0.080000
# lr 2.154435e-07 reg 1.000000e+05 train val accuracy: 0.087000
# lr 2.782559e-06 reg 1.000000e-05 train val accuracy: 0.087000
# lr 2.782559e-06 reg 1.291550e-04 train val accuracy: 0.074000
# lr 2.782559e-06 reg 1.668101e-03 train val accuracy: 0.107000
# lr 2.782559e-06 reg 2.154435e-02 train val accuracy: 0.089000
# lr 2.782559e-06 reg 2.782559e-01 train val accuracy: 0.090000
# lr 2.782559e-06 reg 3.593814e+00 train val accuracy: 0.088000
# lr 2.782559e-06 reg 4.641589e+01 train val accuracy: 0.121000
# lr 2.782559e-06 reg 5.994843e+02 train val accuracy: 0.102000
# lr 2.782559e-06 reg 7.742637e+03 train val accuracy: 0.078000
# lr 2.782559e-06 reg 1.000000e+05 train val accuracy: 0.087000
# lr 3.593814e-05 reg 1.000000e-05 train val accuracy: 0.119000
# lr 3.593814e-05 reg 1.291550e-04 train val accuracy: 0.078000
# lr 3.593814e-05 reg 1.668101e-03 train val accuracy: 0.088000
# lr 3.593814e-05 reg 2.154435e-02 train val accuracy: 0.087000
# lr 3.593814e-05 reg 2.782559e-01 train val accuracy: 0.113000
# lr 3.593814e-05 reg 3.593814e+00 train val accuracy: 0.094000
# lr 3.593814e-05 reg 4.641589e+01 train val accuracy: 0.078000
# lr 3.593814e-05 reg 5.994843e+02 train val accuracy: 0.078000
# lr 3.593814e-05 reg 7.742637e+03 train val accuracy: 0.119000
# lr 3.593814e-05 reg 1.000000e+05 train val accuracy: 0.087000
# lr 4.641589e-04 reg 1.000000e-05 train val accuracy: 0.078000
# lr 4.641589e-04 reg 1.291550e-04 train val accuracy: 0.087000
# lr 4.641589e-04 reg 1.668101e-03 train val accuracy: 0.079000
# lr 4.641589e-04 reg 2.154435e-02 train val accuracy: 0.105000
# lr 4.641589e-04 reg 2.782559e-01 train val accuracy: 0.102000
# lr 4.641589e-04 reg 3.593814e+00 train val accuracy: 0.079000
# lr 4.641589e-04 reg 4.641589e+01 train val accuracy: 0.087000
# lr 4.641589e-04 reg 5.994843e+02 train val accuracy: 0.105000
# lr 4.641589e-04 reg 7.742637e+03 train val accuracy: 0.087000
# lr 4.641589e-04 reg 1.000000e+05 train val accuracy: 0.087000
# lr 5.994843e-03 reg 1.000000e-05 train val accuracy: 0.078000
# lr 5.994843e-03 reg 1.291550e-04 train val accuracy: 0.102000
# lr 5.994843e-03 reg 1.668101e-03 train val accuracy: 0.098000
# lr 5.994843e-03 reg 2.154435e-02 train val accuracy: 0.107000
# lr 5.994843e-03 reg 2.782559e-01 train val accuracy: 0.087000
# lr 5.994843e-03 reg 3.593814e+00 train val accuracy: 0.079000
# lr 5.994843e-03 reg 4.641589e+01 train val accuracy: 0.107000
# lr 5.994843e-03 reg 5.994843e+02 train val accuracy: 0.087000
# lr 5.994843e-03 reg 7.742637e+03 train val accuracy: 0.087000
# lr 5.994843e-03 reg 1.000000e+05 train val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e-05 train val accuracy: 0.430000
# lr 7.742637e-02 reg 1.291550e-04 train val accuracy: 0.440000
# lr 7.742637e-02 reg 1.668101e-03 train val accuracy: 0.444000
# lr 7.742637e-02 reg 2.154435e-02 train val accuracy: 0.426000
# lr 7.742637e-02 reg 2.782559e-01 train val accuracy: 0.159000
# lr 7.742637e-02 reg 3.593814e+00 train val accuracy: 0.102000
# lr 7.742637e-02 reg 4.641589e+01 train val accuracy: 0.087000
# lr 7.742637e-02 reg 5.994843e+02 train val accuracy: 0.087000
# lr 7.742637e-02 reg 7.742637e+03 train val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+05 train val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e-05 train val accuracy: 0.585000
# lr 1.000000e+00 reg 1.291550e-04 train val accuracy: 0.585000
# lr 1.000000e+00 reg 1.668101e-03 train val accuracy: 0.588000
# lr 1.000000e+00 reg 2.154435e-02 train val accuracy: 0.489000
# lr 1.000000e+00 reg 2.782559e-01 train val accuracy: 0.267000
# lr 1.000000e+00 reg 3.593814e+00 train val accuracy: 0.087000
# lr 1.000000e+00 reg 4.641589e+01 train val accuracy: 0.087000
# lr 1.000000e+00 reg 5.994843e+02 train val accuracy: 0.087000
# lr 1.000000e+00 reg 7.742637e+03 train val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+05 train val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.588000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.566

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
